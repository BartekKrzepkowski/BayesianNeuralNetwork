# %%
# !pip3 install edward

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.random.uniform(-100, 100, size=(200, 2))
theta = np.random.uniform(-5, 5, size=(2,1))
labels = (data[:, 1] > (data[:, 0] * theta[0] + theta[1])).astype(int)

plt.scatter(data[:, 0], data[:, 1], c=labels);

# %% [markdown]
# # Bayesian Single Layer Perceptron

# %%
import tensorflow as tf

# %%
def create_bslp(x):
    h = tf.(x @ w_0)
